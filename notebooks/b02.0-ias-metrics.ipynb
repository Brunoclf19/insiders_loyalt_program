# %% [markdown]
# # Como criar um Programa de Fidelidade para empresa?

# %% [markdown]
# # 0.0 Planejamento da solução (IOT)

# %% [markdown]
# ### Input - Entrada

# %% [markdown]
# **1. Problema de Negócio**
#   - Selecionar os clientes mais valiosos para integrar um programa de fidelização
#
# **2. Conjunto de dados**
#   - Vendas de um Ecommerce Online, durante o período de um ano.

# %% [markdown]
# ### Output - Saída

# %% [markdown]
# **1. Indicação das pessoas que farão parte do programa Insiders**
#
#   - Lista: client_id | is_insider
#
# **2. Relatório com as respostas das perguntas de negócio.**
#
#   - Quem são as pessoas elegíveis para participar do programa de Insiders?
#   - Quantos clientes farão parte do grupo?
#   - Quais as principais características desse clientes?
#   - Qual a porcentagem de contribuição do faturamento desses clientes, vinda do Insiders?
#   - Qual a expectativa de faturamento desse grupo para os próximos meses?
#   - Quais as condições para uma pessoa ser elegível ao Insiders?
#   - Quais as condições para uma pessoa ser removida do Insiders?
#   - Qual a garantia que o programa Insiders é melhor que o restante da base?
#   - Quais ações o time de marketing pode realizar para aumentar o faturamento?

# %% [markdown]
# ### Tasks - Tarefas

# %% [markdown]
# **1. Quem são as pessoas elegíveis para participar do programa de Insiders?**
#
#   - O que é ser elegível? O que são clientes de maior "valor"?
#   - Faturamento:
#     - Alto Ticket Médio
#     - Alto LTV (Life Time Value - Gasto durante seu período de vida na empresa)
#     - Baixo Recência
#     - Alto basket size (tamanho da cesta de compra)
#     - Baixa probabilidade de churn (parou de comprar)
#     - Alta previsão LTV
#     - Alta previsão de compra
#
#   - Custo
#     - Baixa taxa de devolução
#
#   - Experiência de Compra
#     - Média alta das avaliações
#
# **2. Quantos clientes farão parte do grupo?**
#
#   - Número total de clientes
#   - Calcula a % do grupo Insiders
#
# **3. Quais as principais características desse clientes?**
#
#   - Escrever características do cliente
#     - Idade
#     - Localização
#
#   - Ecrever características de consumo
#     - Atributos da clusterização (perfil de compra do cliente)
#
# **4. Qual a porcentagem de contribuição do faturamento desses clientes, vinda do Insiders?**
#
#   - Faturamento total do ano
#   - Faturamento do grupo Insiders
#
# **5. Qual a expectativa de faturamento desse grupo para os próximos meses?**
#
#   - LTV do grupo Insiders
#   - Análise de Cohort (Marcação da pessoa, como por exemplo no tempo, perfil de pessoas que entraram no mesmo mês)
#
# **6. Quais as condições para uma pessoa ser elegível ao Insiders?**
#
#   - Definir a periodicidade (recorrência de rodar o modelo)
#   - A pessoa precisa ser similar ou parecida com uma pessoa do grupo
#
# **7. Quais as condições para uma pessoa ser removida do Insiders?**
#
#   - Definir a periodicidade (recorrência de rodar o modelo)
#   - A pessoa precisa ser disimilar ou se distanciar das médias do grupo
#
# **8. Qual a garantia que o programa Insiders é melhor que o restante da base?**
#
#   - Teste A/B
#   - Teste A/B Baysiano
#   - Teste de hipóteses
#
# **9. Quais ações o time de marketing pode realizar para aumentar o faturamento?**
#
#   - Desconto
#   - Preferência de compra
#   - Frete
#   - Visita a empresa

# %% [markdown]
# ## Benchmark de soluções

# %% [markdown]
# ### 1. Desk Research - Pesquisa de soluções das outras empresas

# %% [markdown]
# **Modelo RFM**
#
# **1. Recência**
#
#   * Tempo desde a última compra
#
#   * Responsividade
#
# **2. Frequência**
#
#   * Quantidade de compras em um período
#
#   * Engajamento
#
# **3. Monetária**
#
#   * Total gasto, faturamento
#
#   * Alto valor de compra

# %% [markdown]
# **1. Passo 01:**
#
# * Ordernar os clientes por **Recência**
#
# **2. Passo 02:**
#
# * Dividir a base de clientes de acordo com as notas
#   - Notas de 1 - 5 (5 notas possíveis)
#   - Divide a base de clientes em 5 grupos de 20% cada
#   - Quanto menor o valor, maior nota
#
# * Essa nota se chama R Score
#
# **3. Passo 03:**
#
# * Ordernar os clientes pela **Frequência**
#
# **4. Passo 04:**
#
# * Dar as notas de maneira similar ao passo 02
# * Essa nota se chama F Score
# * Quanto maior o valor, maior a nota
#
# **5. Passo 05:**
#
# * Ordenar pelo **monetário** (faturamento)
#
# **6. Passo 06:**
#
# * Dar as notas de maneira similar ao passo 02 e 04
# * Essa nota de chama M Score
# * Quanto maior o valor, maior a nota
#
# **7. Passo 07:**
#
# * Calcular a média das notas R,F,M
# * RFM Score (pode ordenar por essa média para ter os melhores clientes)

# %% [markdown]
# **Definições que podem ser usadas para dividir os clientes com o RFM e assim direcionar esse clientes para as melhores ações**
#
# **1. Champions**
#
#   - Compra recentes, frequentes com alto valor gasto
#   - Prêmios para esses clientes
#
# **2. Potential Loyalists**
#
#   - Compras recentes, boa frequência e bom valor gasto
#   - Programa de Fidelização e Upsell
#
# **3. New Custumers**
#
#   - Compra recente, baixa frequência
#   - Construção de Relacionamento, ofertas especiais
#
# **4. At Risk Custumers**
#
#   - "Faz tempo que não compra"
#   - Campanhas de reativação, ofertas, produtos
#
# **5. Can't Lose Them**
#
#   - Faz tempo que não compra e não viita o site

# %% [markdown]
# # 0.1 Imports

# %%
import warnings

import pandas  as pd
import numpy   as np
import seaborn as sns
import umap.umap_ as umap
import math

from yellowbrick.cluster   import KElbowVisualizer
from yellowbrick.cluster   import SilhouetteVisualizer
from IPython.display       import Image
from IPython.core.display  import HTML

from matplotlib            import pyplot  as plt
from sklearn               import cluster as c
from sklearn               import metrics as m
from plotly                import express as px

warnings.filterwarnings( 'ignore' )

# %% [markdown]
# # 0.2 Helper Functions

# %%
def jupyter_settings():
    """Definições padrões setadas para o uso o Jupyter Notebook."""
    # %matplotlib inline
    # %pylab inline
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    sns.set()

#Executando a função
jupyter_settings();
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %%
Image(filename=r'C:\Users\bruno.freitas\Documents\repositorio\insiders_loyalty_program\img\modelo_rfm.png')

# %% [markdown]
# Com isso, você consegue entender:
#
# 1. Quem são seus melhores clientes?
#
# 2. Quais clientes estão próximos do Churn?
#
# 3. Quais os potenciais clientes para entrar no programa de Fidelização?
#
# 4. Quais clientes precisam ser retidos?
#
# 5. Quais clientes mais prováveis de responder as campanhas de marketing?

# %% [markdown]
# # 0.3 Load Dataset

# %%
#load dat
df_raw = pd.read_csv(r'C:\Users\bruno.freitas\Documents\repositorio\insiders_loyalty_program\data\Ecommerce\Ecommerce.csv',encoding='unicode_escape')

#drop extra column
df_raw = df_raw.drop(columns=['Unnamed: 8'],axis=1)

# %% [markdown]
# # 1.0. Descrição dos dados

# %%
df_raw.shape
# Out:
# (541909, 8)

# %%
df_raw.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1 Rename Columns

# %%
cols_new = ['invoice_no','stock_code','description','quantity','invoice_date','unit_price','customer_id','country']
df1.columns = cols_new

# %%
df1.columns
# Out:
# Index(['invoice_no', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'customer_id', 'country'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
print(f'Number of rows {df1.shape[0]}')
print(f'Number of cols {df1.shape[1]}')
# Out:
# Number of rows 541909
# Number of cols 8

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %% [markdown]
# ## 1.5 Replace NA

# %%
round(1-(406829/541909), 2)
# Out:
# np.float64(0.25)

# %%
#removendo os na
df1 = df1.dropna(subset=['description','customer_id'])
print('Removed data: {:.2f}'.format(1 - (df1.shape[0] / df_raw.shape[0]))) #Quanto % de NA removeu do total
# Out:
# Removed data: 0.25

# %%
# Restante
df1.shape
# Out:
# (406829, 8)

# %%
#Checando se os NA foram realmente removidos
df1.isna().sum()
# Out:
# invoice_no      0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %% [markdown]
# ## 1.6 Change dtypes

# %%
#invoice date
df1['invoice_date'] = pd.to_datetime(df1['invoice_date'],format='%d-%b-%y')

#customer_id
df1['customer_id'] = df1['customer_id'].astype(int)

# %%
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   2016-11-29        2.55        17850  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6   2016-11-29        3.39        17850  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8   2016-11-29        2.75        17850  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   2016-11-29        3.39        17850  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6   2016-11-29        3.39        17850  United Kingdom

# %%
# Mostrando a mudança dos tipos
df1.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id              int64
# country                 object
# dtype: object

# %% [markdown]
# ## 1.7 Descriptive Statistics

# %% [markdown]
# ### Será feito futuramente

# %% [markdown]
# # 2.0. Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 Feature Creation

# %%
df2.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   2016-11-29        2.55        17850  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6   2016-11-29        3.39        17850  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8   2016-11-29        2.75        17850  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   2016-11-29        3.39        17850  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6   2016-11-29        3.39        17850  United Kingdom

# %%
# Tabela de Referência
df_ref = df2.drop(['invoice_no','stock_code','description','quantity','invoice_date','unit_price','country'],axis=1).drop_duplicates(ignore_index=True)

# %%
df_ref.head()
# Out:
#    customer_id
# 0        17850
# 1        13047
# 2        12583
# 3        13748
# 4        15100

# %%
#Gross Revenue (Faturamento Bruto): qtde * preço
df2['gross_revenue'] = df2['quantity'] * df2['unit_price']

# %%
#Monetary
df_monetary = df2.loc[:,['customer_id','gross_revenue']].groupby('customer_id').sum().reset_index()
df_ref = pd.merge(df_ref, df_monetary, on='customer_id',how='left')

# %%
#Recency
df_recency = df2.loc[:,['customer_id','invoice_date']].groupby('customer_id').max().reset_index()
df_recency['recency_days'] = (df2['invoice_date'].max() - df_recency['invoice_date']).dt.days #vetoriza a série para aplicar o day
df_recency = df_recency[['customer_id','recency_days']].copy()
df_ref = pd.merge(df_ref, df_recency, on='customer_id',how='left')

# %%
#frequency
df_freq = df2.loc[:,['customer_id','invoice_no']].groupby('customer_id').nunique().reset_index()
df_ref = pd.merge(df_ref, df_freq,on='customer_id',how='left')

# %%
df_ref.head()
# Out:
#    customer_id  gross_revenue  recency_days  invoice_no
# 0        17850        5288.63           302          35
# 1        13047        3079.10            31          18
# 2        12583        7187.34             2          18
# 3        13748         948.25            95           5
# 4        15100         635.10           330           6

# %%
df_ref.isna().sum()
# Out:
# customer_id      0
# gross_revenue    0
# recency_days     0
# invoice_no       0
# dtype: int64

# %% [markdown]
# # 3.0. Filtragem de Variáveis

# %%
df3 = df_ref.copy()

# %% [markdown]
# # 4.0. EDA (Exploratory Data Analysis)

# %%
df4 = df3.copy()

# %% [markdown]
# # 5.0. Data Preparation

# %%
df5 = df4.copy()

# %% [markdown]
# # 6.0. Feature Selection

# %%
df6 = df5.copy()

# %% [markdown]
# # 7.0. Hyperparameter Fine - Tunning

# %%
X = df6.drop(columns=['customer_id'],axis=1)

# %%
X.head()
# Out:
#    gross_revenue  recency_days  invoice_no
# 0        5288.63           302          35
# 1        3079.10            31          18
# 2        7187.34             2          18
# 3         948.25            95           5
# 4         635.10           330           6

# %%
#df7 = df6.drop(columns=['customer_id'])
clusters = [2,3,4,5,6]

# %% [markdown]
# ## 7.1 Within-Cluster Sum of Square (WSS)

# %%
wss = []
for k in clusters:
  #model definition
  kmeans = c.KMeans(init='random',n_clusters=k,n_init=10,max_iter=300,random_state=42)

  #model training
  kmeans.fit(X)
  
  #validation
  wss.append(kmeans.inertia_)

#plot wss - Ewbow Method
plt.plot(clusters,wss,linestyle='--',marker='o',color='b');
plt.xlabel('K');
plt.ylabel('WSS');
plt.title('WSS x K');

# %%
from yellowbrick.cluster import KElbowVisualizer

kmeans = KElbowVisualizer(c.KMeans(),k=clusters,timings=False)
kmeans.fit(X)
kmeans.show();

# %% [markdown]
# ## 7.2 Silhouette Score

# %%
kmeans = KElbowVisualizer(c.KMeans(),k=clusters,timings=False,metric='silhouette')
kmeans.fit(X)
kmeans.show();

# %% [markdown]
# ## 7.3 Silhouette Analysis

# %%
fig, ax = plt.subplots(3,2,figsize = (25,18))

for k in clusters:
  km = c.KMeans(init='random',n_clusters=k,n_init=10,max_iter=100,random_state=42);
  q, mod = divmod(k,2) #2 é o mínimo
  vs = SilhouetteVisualizer(km,colors='yellowbrick',ax=ax[q-1][mod]);
  vs.fit(df7);
  vs.finalize();

#A visualização das silhetas não ficou boa pois um cluster fica muito maior que os outros

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score

def analyze_cluster_k(k, X=df7, random_state=42):
    """
    Analisa o K especificado: escala, roda KMeans (com n_init maior), 
    plota silhouette por amostra e embedding 2D (UMAP) com centróides.
    """
    # 1) Escala
    scaler = StandardScaler()
    Xs = scaler.fit_transform(X)

    # 2) KMeans (mais robusto com n_init maior)
    km = c.KMeans(n_clusters=k, n_init=50, random_state=random_state)
    labels = km.fit_predict(Xs)

    # 3) Métricas
    sil_score = m.silhouette_score(Xs, labels)
    ch_score = calinski_harabasz_score(Xs, labels)
    db_score = davies_bouldin_score(Xs, labels)
    print(f'K = {k} | silhouette: {sil_score:.4f} | Calinski-Harabasz: {ch_score:.2f} | Davies-Bouldin: {db_score:.4f}')
    unique, counts = np.unique(labels, return_counts=True)
    print('Tamanho por cluster:', dict(zip(unique.tolist(), counts.tolist())))

    # 4) Silhouette samples + plot
    sil_samples = silhouette_samples(Xs, labels)
    y_lower = 10
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,6))
    # Silhouette plot
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, Xs.shape[0] + (k + 1) * 10])
    for i in range(k):
        ith_sil_vals = sil_samples[labels == i]
        ith_sil_vals.sort()
        size_cluster_i = ith_sil_vals.shape[0]
        y_upper = y_lower + size_cluster_i
        color = plt.cm.nipy_spectral(float(i) / k)
        ax1.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_sil_vals, facecolor=color, edgecolor=color, alpha=0.7)
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10
    ax1.axvline(x=sil_score, color="red", linestyle="--")
    ax1.set_title("Silhouette por amostra")
    ax1.set_xlabel("Coeficiente de Silhueta")
    ax1.set_ylabel("Índice de amostra agrupado por cluster")

    # 5) UMAP 2D + centróides
    umap_model = umap.UMAP(n_components=2, random_state=random_state)
    emb = umap_model.fit_transform(Xs)
    centroids_2d = umap_model.transform(km.cluster_centers_)  # transforma centróides do espaço escalado

    df_plot = pd.DataFrame(emb, columns=['x','y'])
    df_plot['label'] = labels
    scatter = ax2.scatter(df_plot['x'], df_plot['y'], c=df_plot['label'], cmap='tab10', s=8, alpha=0.7)
    ax2.scatter(centroids_2d[:,0], centroids_2d[:,1], marker='X', s=200, c='black', label='centroids')
    ax2.set_title(f'UMAP 2D - K={k}')
    ax2.legend(*scatter.legend_elements(), title="clusters", bbox_to_anchor=(1.05, 1))
    ax2.grid(False)

    plt.tight_layout()
    plt.show()

# Exemplo: rodar para os ks que você já testou
for k_test in clusters:
    analyze_cluster_k(k_test, X=df7)
# Out:
# K = 2 | silhouette: 0.8953 | Calinski-Harabasz: 1904.68 | Davies-Bouldin: 0.7551
# Tamanho por cluster: {0: 26, 1: 4346}
# K = 3 | silhouette: 0.5880 | Calinski-Harabasz: 2998.84 | Davies-Bouldin: 0.7107
# Tamanho por cluster: {0: 1107, 1: 3242, 2: 23}
# K = 4 | silhouette: 0.6113 | Calinski-Harabasz: 3263.20 | Davies-Bouldin: 0.6713
# Tamanho por cluster: {0: 110, 1: 3169, 2: 1087, 3: 6}
# K = 5 | silhouette: 0.5903 | Calinski-Harabasz: 3649.41 | Davies-Bouldin: 0.6606
# Tamanho por cluster: {0: 362, 1: 2914, 2: 1071, 3: 22, 4: 3}
# K = 6 | silhouette: 0.5799 | Calinski-Harabasz: 3958.89 | Davies-Bouldin: 0.6293
# Tamanho por cluster: {0: 393, 1: 1063, 2: 3, 3: 2881, 4: 29, 5: 3}

# %% [markdown]
# ## NOTEBOOKS DE ESTUDOS - DATASETS

# %%
from sklearn                import cluster as c

from sklearn.datasets       import make_blobs
from yellowbrick.cluster    import KElbowVisualizer, SilhouetteVisualizer
from matplotlib             import pyplot  as plt

# %%
# dataset

X, y = make_blobs(n_samples=500, n_features=2,
                  centers = 2,
                  cluster_std=0.5,
                  center_box=(-10.0, 10.0),
                  shuffle=True,
                  random_state=1)

# plot dataset
plt.scatter(X[:,0], X[:,1])

# %%
clusters = [2,3,4,5,6,7,8]

kmeans = KElbowVisualizer(c.KMeans(),k=clusters, metric='distortion', timings=False)
kmeans.fit(X)
kmeans.show();

# %%
ncols = 2
nrows = math.ceil(len(clusters) / ncols)
fig, axes = plt.subplots(nrows, ncols, figsize=(12, 4 * nrows))
axes = axes.flatten()

for idx, k in enumerate(clusters):
    kmeans = c.KMeans(init='k-means++', n_clusters=k, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(X)
    axes[idx].scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap=plt.cm.viridis, s=30)
    axes[idx].set_title(f'Number of Clusters: {k}')

# desliga subplots não usados
for ax in axes[len(clusters):]:
    ax.axis('off')

# %%
# cria grid dinâmico conforme quantidade de ks
ncols = 2
nrows = math.ceil(len(clusters) / ncols)
fig, axes = plt.subplots(nrows, ncols, figsize=(12, 6 * nrows))
axes = axes.flatten() if hasattr(axes, 'flatten') else np.array([axes]).flatten()

for idx, k in enumerate(clusters):
    km = c.KMeans(init='k-means++', n_clusters=k, n_init=10, max_iter=300, random_state=42)
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=axes[idx])
    visualizer.fit(df7 if 'df7' in globals() else X)   # usa df7 quando disponível, senão X
    visualizer.finalize()

# desliga axes não usados
for ax in axes[len(clusters):]:
    ax.axis('off')

plt.tight_layout()

# %%
# fig, ax = plt.subplots(2,2,figsize = (12,8))
# for i in clusters:
#   kmeans = c.KMeans(init='k-means++',n_clusters=i,n_init=10,max_iter=300,random_state=42)
#   kmeans.fit(X)
#   q, mod = divmod(i,2) #2 é o mínimo
#   ax[q-1, mod].scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap=plt.cm.viridis, s=30)
#   ax[q-1, mod].set_title(f'Number of Clusters: {i}');

fig, ax = plt.subplots(2, 2, figsize=(12, 8))
ax = ax.flatten()  # transforma 2x2 em um array de 4 eixos [ax[0], ax[1], ax[2], ax[3]]

for idx, i in enumerate(clusters):
    kmeans = c.KMeans(init='k-means++', n_clusters=i, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(X)
    ax[idx].scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap=plt.cm.viridis, s=30)
    ax[idx].set_title(f'Number of Clusters: {i}')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[86], line 15
#      13     kmeans = c.KMeans(init='k-means++', n_clusters=i, n_init=10, max_iter=300, random_state=42)
#      14     kmeans.fit(X)
# ---> 15     ax[idx].scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap=plt.cm.viridis, s=30)
#      16     ax[idx].set_title(f'Number of Clusters: {i}')
#      17 plt.tight_layout()
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
fig, ax = plt.subplots(2,2,figsize = (12,12))
for i in clusters:
  kmeans = c.KMeans(init='k-means++',n_clusters=i,n_init=10,max_iter=300,random_state=42)
  q, mod = divmod(i,2) #2 é o mínimo
  
  visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick', ax=ax[q-1, mod])
  visualizer.fit(X)
  visualizer.finalize();

# fig, ax = plt.subplots(2, 2, figsize=(12, 12))
# ax = ax.flatten()

# for idx, i in enumerate(clusters):
#     kmeans = c.KMeans(init='k-means++', n_clusters=i, n_init=10, max_iter=300, random_state=42)
#     visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick', ax=ax[idx])
#     visualizer.fit(X)
#     visualizer.finalize()
# plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 6
#       3 kmeans = c.KMeans(init='k-means++',n_clusters=i,n_init=10,max_iter=300,random_state=42)
#       4 q, mod = divmod(i,2) #2 é o mínimo
# ----> 6 visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick', ax=ax[q-1, mod])
#       7 visualizer.fit(X)
#       8 visualizer.finalize();
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %% [markdown]
# # 8.0. Model Training

# %%
df8 = X.copy()

# %%
## 8.1 K-Means
k=3 #definido
#model definition
kmeans = c.KMeans(init='random',n_clusters=k,n_init=10,max_iter=300,random_state=42)
#model training
kmeans.fit(X)
#validation
labels = kmeans.labels_

# %% [markdown]
# ## 8.1 K-Means

# %%
k=4 #definido
#model definition
kmeans = c.KMeans(init='random',n_clusters=k,n_init=10,max_iter=300,random_state=42)
#model training
kmeans.fit(df8)
#validation
labels = kmeans.labels_

# %% [markdown]
# ## 8.2 Cluster Validation

# %%
# WSS (Within-Cluster Sum of Square)
print(f'WSS value: {kmeans.inertia_}')

# SS (Silhouette Score)

print('SS value: {}'.format(m.silhouette_score(df8,labels,metric='euclidean')))
# Out:
# WSS value: 39986809769.41451
# SS value: 0.8149170379682749

# %% [markdown]
# # 9.0 Cluster Analysis

# %%
df9 = df6.copy()
df9['cluster'] = labels
df9.head()
# Out:
#    customer_id  gross_revenue  recency_days  invoice_no  cluster
# 0        17850        5288.63           302          35        0
# 1        13047        3079.10            31          18        3
# 2        12583        7187.34             2          18        0
# 3        13748         948.25            95           5        3
# 4        15100         635.10           330           6        3

# %% [markdown]
# ## 9.1 Visualization Inspection

# %%
vs = SilhouetteVisualizer(kmeans,colors='yellowbrick');
vs.fit(df8);
vs.finalize();

# %%
fig = px.scatter_3d(df9,x='recency_days',y='invoice_no',z='gross_revenue',color='cluster')
fig.show();

# %% [markdown]
# ## 9.2 2d Plot

# %% [markdown]
# Quais features estão bagunçando mais do que organizando os dados?

# %%
df_viz = df9.drop(columns='customer_id',axis=1)
sns.pairplot(df_viz,hue='cluster')

#Os dados estão muito embolados

# %% [markdown]
# ## 9.3 UMAP
# Abordagem por topologia

# %%
#Projetando o cluster em alta dimensionalidade
#Probabilidade dos pontos serem similares dependendo de quantos vizinhos eu considero
#n_neighbors = quanto menor o número, mais local está olhando, dessa forma, a ideia é fazer um for e ir vendo no que se encaixa

reducer = umap.UMAP(random_state = 42,n_neighbors=20)
embedding = reducer.fit_transform (df8)

#embedding
df_viz['embedding_x'] = embedding[:,0]
df_viz['embedding_y'] = embedding[:,1]

#plot UMAP
sns.scatterplot(x='embedding_x', y='embedding_y',hue='cluster',palette=sns.color_palette('hls',n_colors=len(df_viz['cluster'].unique())),
                data=df_viz);

# %% [markdown]
# ## 9.4 Cluster Profile

# %%
#Number of customer
df_cluster = df9.loc[:,['customer_id','cluster']].groupby('cluster').count().reset_index()
df_cluster['perc_customer'] = round((df_cluster['customer_id'] / df_cluster['customer_id'].sum())*100,2)

# %%
df_cluster
# Out:
#    cluster  customer_id  perc_customer  gross_revenue
# 0        0          267           6.11    8089.028652
# 1        1            6           0.14  182181.981667
# 2        2           28           0.64   42614.387143
# 3        3         4071          93.12     946.696250

# %%
#Avg Gross revenue
df_avg_gr = df9.loc[:,['gross_revenue','cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_gr,how='inner',on='cluster')

# %%
#Avg recency days
df_avg_rd = df9.loc[:,['recency_days','cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_rd,how='inner',on='cluster')

#Avg invoice_no
df_avg_in = df9.loc[:,['invoice_no','cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_in,how='inner',on='cluster')
df_cluster

#Avg_ticket 
df_avg_tkt = df9.loc[:,['avg_ticket','cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_tkt,how='inner',on='cluster')
df_cluster
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 19
#      16 df_cluster
#      18 #Avg_ticket
# ---> 19 df_avg_tkt = df9.loc[:,['avg_ticket','cluster']].groupby('cluster').mean().reset_index()
#      20 df_cluster = pd.merge(df_cluster, df_avg_tkt,how='inner',on='cluster')
#      21 df_cluster
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\bruno.freitas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['avg_ticket'] not in index"

# %% [markdown]
# # CONTINUAR A PARTIR DA AULA "5. Aula 028 - Ciclo 02 - Análise de Silhueta" 01:22:00

# %% [markdown]
# # <font color = "red"> 10.0 Deploy do Production </font>
